# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
##Paweł Radzik zad1
def f(x):
    return x*x+5;

# %%
x=np.linspace(-1,1)

plt.plot(x,f(x))
plt.legend("x^2+5")
plt.title("<-1,1>")
plt.grid()
plt.xlabel("x")
plt.ylabel("y")
plt.show()
x=np.linspace(-6,6)
plt.plot(x,f(x))
plt.legend("x^2+5")
plt.title("<-6,6>")
plt.grid()
plt.xlabel("x")
plt.ylabel("y")
plt.show()
x=np.linspace(0,5)
plt.plot(x,f(x))
plt.legend("x^2+5")
plt.title("<0,5>")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.show()

# %%
##Zad 4
d = {'name': ["Pawel", "Michał","Kasia","Kasia","Seba"], 'surname': ["Miły", "Nowak","Kowalaska","Wcisło","Radzik"],'age': [1, 2,4,5,6], 'sex': [1, 1,0,0,1]}
df = pd.DataFrame(data=d)
df
df.info()
df.describe()
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes
#      name    surname  age  sex
# 0   Pawel       Miły    1    1
# 1  Michał      Nowak    2    1
# 2   Kasia  Kowalaska    4    0
